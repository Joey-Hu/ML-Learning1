# %%
# implement of LWR
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import time
from math import exp

# %%
# τfor weight
t = 0.1
# local weights
x_point = 4.5
# Learnable parameter theta
theta = np.zeros([2, 1], dtype=np.float32)
# Learning rate
lr_sto = 0.01
# Epoch
Epoch = 2

# %%
# make dummy regression data
noise = np.random.normal(0, 2, size=250)
X = np.linspace(-5, 5, 250)
y = X**2 + 2 + noise
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# for theata0, x0 = 1
o_train = np.ones([X_train.shape[0], 1], dtype=X_train.dtype)
o_test = np.ones([X_test.shape[0], 1], dtype=X_test.dtype)
X_train = np.concatenate((o_train, np.reshape(X_train, (o_train.shape))), axis=1)
X_test = np.concatenate((o_test, np.reshape(X_test, (o_test.shape))), axis=1)

# %%
plt.scatter(X_test[:, 1], y_test, c='red', edgecolors='white')
plt.scatter(X_train[:, 1], y_train, c='orange', edgecolors='white')
plt.ylim((-8, 42))
plt.xlim((-7.5, 7.5))
plt.show()

# %%
def hypothesis(x, θ):

	# hypothesis
	h_x = np.matmul(θ.T, x)

	return h_x

# %%
def loss_function(h_x,x,x_point,y):
    w = exp(-(x[1] - x_point)**2/(2*(t**2)))
    # loss_function
    J = 1 / 2 * w * (h_x - y) * (h_x - y)
    return J

def update_parameters(theta, h_x, x, x_point, y, lr):
    w = exp(-(x[1] - x_point)**2 / (2*(t**2)))
    x = np.reshape(x, theta.shape)
    theta = theta - lr *w *(h_x - y) *x
    
    return theta

# %%
# for plotting
p_x = np.linspace(-x_point-3, x_point+3, 100)

# stochastic gradient descent
plt.ion()
for epoch in range(Epoch):
	for x, y in zip(X_train, y_train):
		# make hypothesis
		h_x = hypothesis(x, theta)
		# compute loss
		loss = loss_function(h_x, x, x_point, y)
		# Excecute gradient descent to update parameters
		theta = update_parameters(theta, h_x, x, x_point, y, lr_sto)

		print("[{0}/{1}], loss: {2}".format(epoch+1, Epoch, loss[0]))
# 		plt.cla()
		plt.scatter(X_train[:, 1], y_train, c='purple', marker='o', edgecolors='white')
		plt.ylim((-8, 42))
		plt.xlim((-7.5, 7.5))
		plt.plot(p_x, theta[1, 0] * p_x + theta[0, 0], c='orange')
		plt.pause(0.01)
plt.ioff()
plt.show()
# Out:
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.008853671950658318
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 4.122091767182274e-194
# [1/2], loss: 2.087140241250972e-65
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 1.1697287778097961e-33
# [1/2], loss: 6.528449993166082e-06
# [1/2], loss: 0.0
# [1/2], loss: 1.5923441254190406e-16
# [1/2], loss: 0.0
# [1/2], loss: 1.6908359473227153e-25
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 4.55061182481218e-124
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 1.4433863472306792e-111
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 1.7311822486898613e-204
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.019579905844111557
# [1/2], loss: 179.21825521706393
# [1/2], loss: 1.3122526618707076e-78
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 1.225393547047597e-31
# [1/2], loss: 3.8820102577922316e-151
# [1/2], loss: 2.3433018781543597e-132
# [1/2], loss: 0.00027472422806838683
# [1/2], loss: 6.782628957250989e-288
# [1/2], loss: 1.772335854156714e-23
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 1.7036852975725305e-136
# [1/2], loss: 0.0
# [1/2], loss: 2.4094497892365127e-36
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0032585953229846824
# [1/2], loss: 0.0
# [1/2], loss: 5.307506280211503e-257
# [1/2], loss: 1.0057820907190176e-44
# [1/2], loss: 0.0
# [1/2], loss: 7.13640936787772e-86
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 53.739824747619295
# [1/2], loss: 3.724675937453276e-146
# [1/2], loss: 1.0603803827981397e-13
# [1/2], loss: 1.1383799652664133e-115
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 2.6137996222083377e-159
# [1/2], loss: 8.468211088142105e-69
# [1/2], loss: 0.0
# [1/2], loss: 8.440388399285403e-294
# [1/2], loss: 268.8158902939114
# [1/2], loss: 0.0
# [1/2], loss: 7.515752378302337e-171
# [1/2], loss: 3.1491272693986385e-11
# [1/2], loss: 0.0
# [1/2], loss: 4.675533567017171
# [1/2], loss: 1.234659193153759e-75
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# [1/2], loss: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-929260b73142> in <module>
#      15                 print("[{0}/{1}], loss: {2}".format(epoch+1, Epoch, loss[0]))
#      16 #               plt.cla()
# ---> 17                 plt.scatter(X_train[:, 1], y_train, c='purple', marker='o', edgecolors='white')
#      18                 plt.ylim((-8, 42))
#      19                 plt.xlim((-7.5, 7.5))
#
# c:\python35-32\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2858         vmin=None, vmax=None, alpha=None, linewidths=None, verts=None,
#    2859         edgecolors=None, *, data=None, **kwargs):
# -> 2860     __ret = gca().scatter(
#    2861         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# c:\python35-32\lib\site-packages\matplotlib\pyplot.py in gca(**kwargs)
#     933     matplotlib.figure.Figure.gca : The figure's gca method.
#     934     """
# --> 935     return gcf().gca(**kwargs)
#     936
#     937
#
# c:\python35-32\lib\site-packages\matplotlib\figure.py in gca(self, **kwargs)
#    1861
#    1862         # no axes found, so create one which spans the figure
# -> 1863         return self.add_subplot(1, 1, 1, **kwargs)
#    1864
#    1865     def sca(self, a):
#
# c:\python35-32\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# c:\python35-32\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      68
#      69         # _axes_class is set in the subplot_class_factory
# ---> 70         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      71         # add a layout box to this, for both the full axis, and the poss
#      72         # of the axis.  We need both because the axes may become smaller
#
# c:\python35-32\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     489         self._rasterization_zorder = None
#     490         self._connected = {}  # a dict from events to (id, func)
# --> 491         self.cla()
#     492
#     493         # funcs used to format x and y - fall back on major formatters
#
# c:\python35-32\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1048         self.containers = []
#    1049
# -> 1050         self.grid(False)  # Disable grid on init to use rcParameter
#    1051         self.grid(self._gridOn, which=rcParams['axes.grid.which'],
#    1052                   axis=rcParams['axes.grid.axis'])
#
# c:\python35-32\lib\site-packages\matplotlib\axes\_base.py in grid(self, b, which, axis, **kwargs)
#    2762
#    2763         if axis == 'x' or axis == 'both':
# -> 2764             self.xaxis.grid(b, which=which, **kwargs)
#    2765         if axis == 'y' or axis == 'both':
#    2766             self.yaxis.grid(b, which=which, **kwargs)
#
# c:\python35-32\lib\site-packages\matplotlib\axis.py in grid(self, b, which, **kwargs)
#    1455                 self._gridOnMajor = b
#    1456             self.set_tick_params(which='major', gridOn=self._gridOnMajor,
# -> 1457                                  **gridkw)
#    1458         self.stale = True
#    1459
#
# c:\python35-32\lib\site-packages\matplotlib\axis.py in set_tick_params(self, which, reset, **kw)
#     860         else:
#     861             if which == 'major' or which == 'both':
# --> 862                 for tick in self.majorTicks:
#     863                     tick._apply_params(**self._major_tick_kw)
#     864             if which == 'minor' or which == 'both':
#
# c:\python35-32\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     675             if self._major:
#     676                 instance.majorTicks = []
# --> 677                 tick = instance._get_tick(major=True)
#     678                 instance.majorTicks.append(tick)
#     679                 return instance.majorTicks
#
# c:\python35-32\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1816         else:
#    1817             tick_kw = self._minor_tick_kw
# -> 1818         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1819
#    1820     def _get_label(self):
#
# c:\python35-32\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     172         self.apply_tickdir(tickdir)
#     173
# --> 174         self.tick1line = self._get_tick1line()
#     175         self.tick2line = self._get_tick2line()
#     176         self.gridline = self._get_gridline()
#
# c:\python35-32\lib\site-packages\matplotlib\axis.py in _get_tick1line(self)
#     468                           linestyle='None', marker=self._tickmarkers[0],
#     469                           markersize=self._size,
# --> 470                           markeredgewidth=self._width, zorder=self._zorder)
#     471         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     472         self._set_artist_props(l)
#
# c:\python35-32\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     384         self._color = None
#     385         self.set_color(color)
# --> 386         self._marker = MarkerStyle(marker, fillstyle)
#     387
#     388         self._markevery = None
#
# c:\python35-32\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     243         self._marker_function = None
#     244         self.set_fillstyle(fillstyle)
# --> 245         self.set_marker(marker)
#     246
#     247     def _recache(self):
#
# c:\python35-32\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     316
#     317         self._marker = marker
# --> 318         self._recache()
#     319
#     320     def get_path(self):
#
# c:\python35-32\lib\site-packages\matplotlib\markers.py in _recache(self)
#     256         self._capstyle = 'butt'
#     257         self._filled = True
# --> 258         self._marker_function()
#     259
#     260     def __bool__(self):
#
# c:\python35-32\lib\site-packages\matplotlib\markers.py in _set_tickdown(self)
#     772
#     773     def _set_tickdown(self):
# --> 774         self._transform = Affine2D().scale(1.0, -1.0)
#     775         self._snap_threshold = 1.0
#     776         self._filled = False
#
# c:\python35-32\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    2040         scale_mtx = np.array(
#    2041             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 2042         self._mtx = np.dot(scale_mtx, self._mtx)
#    2043         self.invalidate()
#    2044         return self
#
# KeyboardInterrupt:

# %%
# test
p_y = theta[1, 0] * p_x + theta[0, 0]
plt.scatter(X_test[:, 1], y_test, c='red', marker='o', edgecolors='white')
plt.ylim((-8, 42))
plt.xlim((-7.5, 7.5))
plt.plot(p_x, p_y, c='orange')
plt.show()
