# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import time

# 制作虚拟回归数据
X, y = datasets.make_regression(n_samples=250, n_features=1, noise=20, random_state=0, bias=50)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
# theata0和x0 = 1
o_train = np.ones([X_train.shape[0], 1], dtype=X_train.dtype)
o_test = np.ones([X_test.shape[0], 1], dtype=X_test.dtype)
X_train = np.concatenate((o_train, X_train), axis=1)
X_test = np.concatenate((o_test, X_test), axis=1)

# %%
# 显示数据
plt.scatter(X_test[:, 1], y_test, c='red', edgecolors='white')
plt.scatter(X_train[:, 1], y_train, c='orange', edgecolors='white')
plt.ylim((-25, 125))
plt.xlim((-3, 3))
plt.show()

# %%
# 待学习的参数theata
THEATA = np.zeros([2,1], dtype=np.float32)
# 学习率
lr_sto = 0.01
lr_bat = 0.0001
Epoch = 2

# %%
def hyppthesis(x, theata):
    # np.matmul两个矩阵乘积
    h_x = np.matmul(theata.T, x)
    return h_x

# 针对单个训练样本
def loss_function(h_x, y):
    J = 1 / 2 * (h_x-y) * (h_x-y)
    return J

def update_parameters(THEATA, h_x, x, y, lr):
    x = np.reshape(x, THEATA.shape)
    THEATA = THEATA - lr * (h_x - y) *x
    return THEATA

def batch_update_parameters(THETA, gradient, lr):

    THETA = THETA - lr *gradient

    return THETA

# %%
p_x = np.linspace(-2.5, 2.5, 50)

# %%
plt.ion()
for epoch in range(Epoch):
    for x, y in zip(X_train, y_train):
        h_x = hyppthesis(x,THEATA)
        loss = loss_function(h_x, y)
        THEATA = update_parameters(THEATA, h_x, x, y, lr_sto)
        
        print("[{0}/{1}], loss: {2}".format(epoch+1, Epoch, loss[0]))
        plt.cla()
        plt.scatter(X_train[:, 1], y_train, c='purple', marker='o', edgecolors='white')
        plt.plot(p_x, THEATA[1, 0] * p_x + THEATA[0, 0], c='orange')
        plt.ylim((-25, 125))
        plt.xlim((-3, 3))
        plt.pause(0.01)
plt.ioff()
plt.show()
# Out:
# [1/2], loss: 297.09845372081907
# [1/2], loss: 20.38305944024548
# [1/2], loss: 1424.371612099956
# [1/2], loss: 4724.557623380684
# [1/2], loss: 1055.1130292917471
# [1/2], loss: 3191.114104196751
# [1/2], loss: 812.6271872200965
# [1/2], loss: 1296.5181923173486
# [1/2], loss: 156.64841483045
# [1/2], loss: 1043.1878435954375
# [1/2], loss: 1815.4927899100803
# [1/2], loss: 1143.4857902951114
# [1/2], loss: 2137.2024158253153
# [1/2], loss: 1825.612865400344
# [1/2], loss: 272.9551378346918
# [1/2], loss: 2898.827680025184
# [1/2], loss: 378.18813239413277
# [1/2], loss: 1280.3660693108325
# [1/2], loss: 963.9064908301925
# [1/2], loss: 15.655734893540258
# [1/2], loss: 1783.9010225890518
# [1/2], loss: 872.4300744149724
# [1/2], loss: 1267.2245282105905
# [1/2], loss: 963.887377389142
# [1/2], loss: 521.0690450535819
# [1/2], loss: 10.038781448009285
# [1/2], loss: 979.8558614258202
# [1/2], loss: 1651.1416089208242
# [1/2], loss: 1483.2066786027144
# [1/2], loss: 4.624336147357834
# [1/2], loss: 1775.0824519070723
# [1/2], loss: 3794.785047653444
# [1/2], loss: 5139.933515697874
# [1/2], loss: 2475.191067379169
# [1/2], loss: 51.97580723355596
# [1/2], loss: 969.6013032859156
# [1/2], loss: 3.9222348782033456
# [1/2], loss: 628.8709304400452
# [1/2], loss: 23.935992697671697
# [1/2], loss: 12.893881736674812
# [1/2], loss: 623.9089185750364
# [1/2], loss: 1995.9602244270875
# [1/2], loss: 104.33158249227459
# [1/2], loss: 363.88189856938686
# [1/2], loss: 119.34724381906706
# [1/2], loss: 426.1450704928584
# [1/2], loss: 27.940545373887975
# [1/2], loss: 269.65484677766074
# [1/2], loss: 482.022546179009
# [1/2], loss: 600.7491802848641
# [1/2], loss: 364.84659622102515
# [1/2], loss: 21.56450557293156
# [1/2], loss: 144.13816236701493
# [1/2], loss: 129.02765596328203
# [1/2], loss: 265.04747388125537
# [1/2], loss: 254.7570572806842
# [1/2], loss: 473.5840095223212
# [1/2], loss: 86.69464621517008
# [1/2], loss: 1.087192778800993
# [1/2], loss: 953.5667328808382
# [1/2], loss: 171.37200481148378
# [1/2], loss: 533.8266162544163
# [1/2], loss: 2227.54596287306
# [1/2], loss: 585.0506284072208
# [1/2], loss: 1117.6136629997961
# [1/2], loss: 171.44762171879404
# [1/2], loss: 611.1507344062828
# [1/2], loss: 1725.9089285899333
# [1/2], loss: 928.6712040588501
# [1/2], loss: 92.37857613465185
# [1/2], loss: 0.9259495179759366
# [1/2], loss: 21.468827862512143
# [1/2], loss: 680.5397358942025
# [1/2], loss: 251.019211105829
# [1/2], loss: 193.46101016731035
# [1/2], loss: 1.6447473571037343
# [1/2], loss: 5.301223039494727
# [1/2], loss: 3184.484942765118
# [1/2], loss: 48.58282159723367
# [1/2], loss: 749.6123644927229
# [1/2], loss: 85.44035072419204
# [1/2], loss: 71.68797280865628
# [1/2], loss: 50.98798517663783
# [1/2], loss: 461.9634900128906
# [1/2], loss: 37.862527236357714
# [1/2], loss: 924.0328641637007
# [1/2], loss: 1205.8338616538858
# [1/2], loss: 700.9527607545854
# [1/2], loss: 979.4507177191869
# [1/2], loss: 100.71953742691778
# [1/2], loss: 1247.2428844849987
# [1/2], loss: 137.80621768122322
# [1/2], loss: 314.43120468162965
# [1/2], loss: 264.86188810222706
# [1/2], loss: 201.84529636325183
# [1/2], loss: 237.02599320842958
# [1/2], loss: 73.75628508479797
# [1/2], loss: 692.0123991039255
# [1/2], loss: 20.147247039466595
# [1/2], loss: 741.73186395084
# [1/2], loss: 583.2308351257927
# [1/2], loss: 754.9952507839733
# [1/2], loss: 25.509351052068403
# [1/2], loss: 60.37695667555392
# [1/2], loss: 132.81225007365194
# [1/2], loss: 152.65065106131797
# [1/2], loss: 27.10193007675777
# [1/2], loss: 410.50381540743365
# [1/2], loss: 118.8554004269775
# [1/2], loss: 206.30750878623095
# [1/2], loss: 42.694561355679625
# [1/2], loss: 107.71257825498967
# [1/2], loss: 97.9404964457752
# [1/2], loss: 34.63508695758073
# [1/2], loss: 77.96378451448021
# [1/2], loss: 2069.1676828589157
# [1/2], loss: 19.191876323990815
# [1/2], loss: 771.9350204596728
# [1/2], loss: 396.2361553384406
# [1/2], loss: 16.01421734661489
# [1/2], loss: 313.24522928398386
# [1/2], loss: 1940.7494531241252
# [1/2], loss: 365.8237280017424
# [1/2], loss: 1.3915104441684012
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-333a1283b44f> in <module>
#      12         plt.ylim((-25, 125))
#      13         plt.xlim((-3, 3))
# ---> 14         plt.pause(0.01)
#      15 plt.ioff()
#      16 plt.show()
#
# c:\python35-32\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     292         if canvas.figure.stale:
#     293             canvas.draw_idle()
# --> 294         show(block=False)
#     295         canvas.start_event_loop(interval)
#     296     else:
#
# c:\python35-32\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# c:\python35-32\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# c:\python35-32\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     302             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     303         else:
# --> 304             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     305             if not format_dict:
#     306                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\python35-32\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <c:\python35-32\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# c:\python35-32\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\python35-32\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\python35-32\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\python35-32\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# c:\python35-32\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2047                         orientation=orientation,
#    2048                         dryrun=True,
# -> 2049                         **kwargs)
#    2050                     renderer = self.figure._cachedRenderer
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# c:\python35-32\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     521                 cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     522             _png.write_png(renderer._renderer, fh,
# --> 523                             self.figure.dpi, metadata=metadata)
#     524
#     525     def print_to_buffer(self):
#
# KeyboardInterrupt:

# %%
p_y = THEATA[1, 0] * X_test + THEATA[0, 0]
plt.scatter(X_test[:, 1], y_test, c='red', marker='o', edgecolors='white')
plt.plot(X_test, p_y, c='orange')
plt.show()
