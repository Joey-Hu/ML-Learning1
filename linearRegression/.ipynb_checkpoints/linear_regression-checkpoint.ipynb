# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import time

# 制作虚拟回归数据
X, y = datasets.make_regression(n_samples=250, n_features=1, noise=20, random_state=0, bias=50)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
# theata0和x0 = 1
o_train = np.ones([X_train.shape[0], 1], dtype=X_train.dtype)
o_test = np.ones([X_test.shape[0], 1], dtype=X_test.dtype)
X_train = np.concatenate((o_train, X_train), axis=1)
X_test = np.concatenate((o_test, X_test), axis=1)

# %%
# 显示数据
plt.scatter(X_test[:, 1], y_test, c='red', edgecolors='white')
plt.scatter(X_train[:, 1], y_train, c='orange', edgecolors='white')
plt.ylim((-25, 125))
plt.xlim((-3, 3))
plt.show()

# %%
# 待学习的参数theata
THEATA = np.zeros([2,1], dtype=np.float32)
# 学习率
lr_sto = 0.01
lr_bat = 0.0001
Epoch = 2

# %%
def hyppthesis(x, theata):
    # np.matmul两个矩阵乘积
    h_x = np.matmul(theata.T, x)
    return h_x

# 针对单个训练样本
def loss_function(h_x, y):
    J = 1 / 2 * (h_x-y) * (h_x-y)
    return J

def update_parameter(THEATA, h_x, x, y, lr):
    x = np.reshape(x, THEATA.shape)
    THEATA = THEATA - lr * (h_x - y) *x
    return THEATA

def batch_update_parameters(THETA, gradient, lr):

    THETA = THETA - lr *gradient

    return THETA

# %%
p_x = np.linspace(-2.5, 2.5, 50)

# %%
plt.ion()
for epoch in range(Epoch):
    for x, y in zip(X_train, y_train):
        h_x = hyppthesis(x,THEATA)
        loss = loss_function(h_x, y)
        update_parameter(THEATA, h_x, x, y, lr_sto)
        
        print("[{0}/{1}], loss: {2}".format(epoch+1, Epoch, loss[0]))
        plt.cla()
        plt.scatter(X_train[:, 1], y_train, c='purple', marker='o', edgecolors='white')
        plt.plot(p_x, THEATA[1, 0] * p_x + THEATA[0, 0], c='orange')
        plt.ylim((-25, 125))
        plt.xlim((-3, 3))
        plt.pause(0.01)
plt.ioff()
plt.show()
# Out:
# [1/2], loss: 297.09845372081907
# [1/2], loss: 22.47201452119178
# [1/2], loss: 1451.1382608076651
# [1/2], loss: 4647.356275622126
# [1/2], loss: 1093.1915964948496
# [1/2], loss: 3413.149718068246
# [1/2], loss: 945.4461068432737
# [1/2], loss: 1505.570061676942
# [1/2], loss: 248.89639048587978
# [1/2], loss: 1186.9599617340596
# [1/2], loss: 2283.8143138423047
# [1/2], loss: 1460.0656019007101
# [1/2], loss: 2534.986913019856
# [1/2], loss: 2226.4673438792097
# [1/2], loss: 371.3790702159648
# [1/2], loss: 3552.2346058417347
# [1/2], loss: 651.8248990678138
# [1/2], loss: 1784.787021111241
# [1/2], loss: 1324.3046582891016
# [1/2], loss: 89.17614927335299
# [1/2], loss: 2408.0626731820525
# [1/2], loss: 1388.8605760517703
# [1/2], loss: 1974.210399813201
# [1/2], loss: 1336.6030309352714
# [1/2], loss: 1079.9206572729854
# [1/2], loss: 10.227050602086255
# [1/2], loss: 1507.9189993162404
# [1/2], loss: 2666.2589518780537
# [1/2], loss: 2451.3481402618363
# [1/2], loss: 70.59561159576985
# [1/2], loss: 2946.582062294216
# [1/2], loss: 5543.455392739888
# [1/2], loss: 6926.864301107307
# [1/2], loss: 3934.292211177311
# [1/2], loss: 314.57096391507656
# [1/2], loss: 1374.8152671268726
# [1/2], loss: 23.36035159873174
# [1/2], loss: 1203.3753249460303
# [1/2], loss: 183.93366788343903
# [1/2], loss: 42.82818691919409
# [1/2], loss: 1052.8276664492546
# [1/2], loss: 4119.632641339448
# [1/2], loss: 469.6442743501885
# [1/2], loss: 1315.1897894243555
# [1/2], loss: 5.778505855785926
# [1/2], loss: 1020.025886946959
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-9b2374456a6c> in <module>
#      12         plt.ylim((-25, 125))
#      13         plt.xlim((-3, 3))
# ---> 14         plt.pause(0.01)
#      15 plt.ioff()
#      16 plt.show()
#
# c:\python35-32\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     291         canvas = manager.canvas
#     292         if canvas.figure.stale:
# --> 293             canvas.draw_idle()
#     294         show(block=False)
#     295         canvas.start_event_loop(interval)
#
# c:\python35-32\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# c:\python35-32\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# c:\python35-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\python35-32\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# c:\python35-32\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# c:\python35-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\python35-32\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# c:\python35-32\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# c:\python35-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\python35-32\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1188
#    1189         for tick in ticks_to_draw:
# -> 1190             tick.draw(renderer)
#    1191
#    1192         # scale up the axis label box to also find the neighbors, not
#
# c:\python35-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\python35-32\lib\site-packages\matplotlib\axis.py in draw(self, renderer)
#     297             self.gridline.draw(renderer)
#     298         if self.tick1On:
# --> 299             self.tick1line.draw(renderer)
#     300         if self.tick2On:
#     301             self.tick2line.draw(renderer)
#
# c:\python35-32\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# c:\python35-32\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     726
#     727         if self._invalidy or self._invalidx:
# --> 728             self.recache()
#     729         self.ind_offset = 0  # Needed for contains() method.
#     730         if self._subslice and self.axes:
#
# c:\python35-32\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     647             y = self._y
#     648
# --> 649         self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     650         self._x, self._y = self._xy.T  # views
#     651
#
# KeyboardInterrupt:
